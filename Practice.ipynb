# %% [markdown]
# # practice notebook

# %% [markdown]
# #### i practice or try to get logic here in this notebook

# %%
print("hello")
# Out:
# hello

# %%
def print_hello(matrix):
    for i in range(len(matrix)):  
        for j in range(i):
            if matrix[i][j] == 0:
                for k in range(len(matrix)):
                    matrix[i][k] = 0
                    matrix[k][j] = 0

# %%
# matrix = [[1,2,3],[4,5,6],[7,8,9]]

# %%
matrix=[[1,2,3],[4,5,6],[7,8,9]]
print(len(matrix[0]))
# Out:
# 3

# %%
i=0
for j in range(i+1,len(matrix)):
    matrix[i][j],matrix[j][i] = matrix[j][i],matrix[i][j]
    if j==len(matrix)-1:
        i+=1


print(matrix)
# Out:
# [[1, 4, 7], [2, 5, 6], [3, 8, 9]]
